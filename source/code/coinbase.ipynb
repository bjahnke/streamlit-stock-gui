# %%
"""

"""
from pprint import pprint
from json import dumps
from coinbase.rest import RESTClient
from coinbase.rest.types.accounts_types import ListAccountsResponse
from coinbase.rest.types.product_types import GetProductCandlesResponse
import pandas as pd
from dotenv import load_dotenv
import os
load_dotenv()

client = RESTClient(key_file=os.getenv('COINBASE_API_KEY_FILE'))

# %%
accounts: ListAccountsResponse = client.get_accounts()

# pprint(accounts.to_dict(), indent=2)


accounts.accounts
# Out:
# [{'uuid': '5018c40c-69b4-5fdc-bfa4-c520c4266a6f', 'name': 'AAVE Wallet', 'currency': 'AAVE', 'available_balance': {'value': '0.0002021532553941', 'currency': 'AAVE'}, 'default': True, 'active': True, 'created_at': '2024-11-24T17:17:42.794Z', 'updated_at': '2024-11-24T17:17:42.794Z', 'deleted_at': None, 'type': 'ACCOUNT_TYPE_CRYPTO', 'ready': True, 'hold': {'value': '0', 'currency': 'AAVE'}, 'retail_portfolio_id': 'c6178073-3d59-5f24-8d75-2df8c3d375c8', 'platform': 'ACCOUNT_PLATFORM_CONSUMER'},
#  {'uuid': 'cd321efa-9174-504c-8fe9-4239c310555e', 'name': 'BCH Wallet', 'currency': 'BCH', 'available_balance': {'value': '0', 'currency': 'BCH'}, 'default': True, 'active': True, 'created_at': '2024-11-06T06:37:14.234Z', 'updated_at': '2024-11-06T06:37:14.234Z', 'deleted_at': None, 'type': 'ACCOUNT_TYPE_CRYPTO', 'ready': True, 'hold': {'value': '0', 'currency': 'BCH'}, 'retail_portfolio_id': 'c6178073-3d59-5f24-8d75-2df8c3d375c8', 'platform': 'ACCOUNT_PLATFORM_CONSUMER'},
#  {'uuid': '1d8b2a2c-7ce6-5a65-8449-f4f31226e564', 'name': 'MATIC Wallet', 'currency': 'MATIC', 'available_balance': {'value': '0', 'currency': 'MATIC'}, 'default': True, 'active': True, 'created_at': '2024-11-06T05:57:14.992Z', 'updated_at': '2024-11-06T05:57:14.992Z', 'deleted_at': None, 'type': 'ACCOUNT_TYPE_CRYPTO', 'ready': True, 'hold': {'value': '0', 'currency': 'MATIC'}, 'retail_portfolio_id': 'c6178073-3d59-5f24-8d75-2df8c3d375c8', 'platform': 'ACCOUNT_PLATFORM_CONSUMER'},
#  {'uuid': '3f337721-7d12-54c8-a2a1-823f53e09124', 'name': 'USDC Wallet', 'currency': 'USDC', 'available_balance': {'value': '0', 'currency': 'USDC'}, 'default': True, 'active': True, 'created_at': '2024-03-19T20:16:48.591Z', 'updated_at': '2024-12-02T19:12:24.793Z', 'deleted_at': None, 'type': 'ACCOUNT_TYPE_CRYPTO', 'ready': True, 'hold': {'value': '0', 'currency': 'USDC'}, 'retail_portfolio_id': 'c6178073-3d59-5f24-8d75-2df8c3d375c8', 'platform': 'ACCOUNT_PLATFORM_CONSUMER'},
#  {'uuid': 'ad90142c-1bb7-567f-a72f-2394bcf33850', 'name': 'ALGO Wallet', 'currency': 'ALGO', 'available_balance': {'value': '0', 'currency': 'ALGO'}, 'default': True, 'active': True, 'created_at': '2021-08-21T19:48:41.243Z', 'updated_at': '2021-08-21T19:48:41.243Z', 'deleted_at': None, 'type': 'ACCOUNT_TYPE_CRYPTO', 'ready': True, 'hold': {'value': '0', 'currency': 'ALGO'}, 'retail_portfolio_id': 'c6178073-3d59-5f24-8d75-2df8c3d375c8', 'platform': 'ACCOUNT_PLATFORM_CONSUMER'},
#  {'uuid': 'f0de125d-b70b-5782-b5e7-a44d23dfc303', 'name': 'ZEC Wallet', 'currency': 'ZEC', 'available_balance': {'value': '0', 'currency': 'ZEC'}, 'default': True, 'active': True, 'created_at': '2021-08-10T22:06:42.250Z', 'updated_at': '2021-08-10T22:06:42.384Z', 'deleted_at': None, 'type': 'ACCOUNT_TYPE_CRYPTO', 'ready': True, 'hold': {'value': '0', 'currency': 'ZEC'}, 'retail_portfolio_id': 'c6178073-3d59-5f24-8d75-2df8c3d375c8', 'platform': 'ACCOUNT_PLATFORM_CONSUMER'},
#  {'uuid': '430cd5c9-6727-56c2-af79-3105624f4de4', 'name': 'ETC Wallet', 'currency': 'ETC', 'available_balance': {'value': '0', 'currency': 'ETC'}, 'default': True, 'active': True, 'created_at': '2021-06-21T16:49:32.530Z', 'updated_at': '2021-06-21T16:49:32.530Z', 'deleted_at': None, 'type': 'ACCOUNT_TYPE_CRYPTO', 'ready': True, 'hold': {'value': '0', 'currency': 'ETC'}, 'retail_portfolio_id': 'c6178073-3d59-5f24-8d75-2df8c3d375c8', 'platform': 'ACCOUNT_PLATFORM_CONSUMER'},
#  {'uuid': '99e94d52-33ad-58a9-8832-2bddd7b8a9cd', 'name': 'ZRX Wallet', 'currency': 'ZRX', 'available_balance': {'value': '0', 'currency': 'ZRX'}, 'default': True, 'active': True, 'created_at': '2021-06-21T16:49:32.041Z', 'updated_at': '2021-06-21T16:49:32.267Z', 'deleted_at': None, 'type': 'ACCOUNT_TYPE_CRYPTO', 'ready': True, 'hold': {'value': '0', 'currency': 'ZRX'}, 'retail_portfolio_id': 'c6178073-3d59-5f24-8d75-2df8c3d375c8', 'platform': 'ACCOUNT_PLATFORM_CONSUMER'},
#  {'uuid': 'f8b2dd59-826a-5388-9fb6-44ef6f98a0a6', 'name': 'ETH Wallet', 'currency': 'ETH', 'available_balance': {'value': '1.1670377457972901', 'currency': 'ETH'}, 'default': True, 'active': True, 'created_at': '2021-06-20T02:23:58.606Z', 'updated_at': '2024-11-18T06:46:51.145Z', 'deleted_at': None, 'type': 'ACCOUNT_TYPE_CRYPTO', 'ready': True, 'hold': {'value': '0', 'currency': 'ETH'}, 'retail_portfolio_id': 'c6178073-3d59-5f24-8d75-2df8c3d375c8', 'platform': 'ACCOUNT_PLATFORM_CONSUMER'},
#  {'uuid': 'a3e14038-9169-5d91-abe8-da3e59dd4d05', 'name': 'ADA Wallet', 'currency': 'ADA', 'available_balance': {'value': '0', 'currency': 'ADA'}, 'default': True, 'active': True, 'created_at': '2021-06-20T02:21:35.250Z', 'updated_at': '2024-08-07T23:20:13.406Z', 'deleted_at': None, 'type': 'ACCOUNT_TYPE_CRYPTO', 'ready': True, 'hold': {'value': '0', 'currency': 'ADA'}, 'retail_portfolio_id': 'c6178073-3d59-5f24-8d75-2df8c3d375c8', 'platform': 'ACCOUNT_PLATFORM_CONSUMER'},
#  {'uuid': '31b0fc20-dd46-51e8-bebf-edf75f481de0', 'name': 'Cash (USD)', 'currency': 'USD', 'available_balance': {'value': '10759.2585445237152', 'currency': 'USD'}, 'default': False, 'active': True, 'created_at': '2021-06-19T03:31:53.668Z', 'updated_at': '2024-12-02T19:12:25.173Z', 'deleted_at': None, 'type': 'ACCOUNT_TYPE_FIAT', 'ready': True, 'hold': {'value': '0', 'currency': 'USD'}, 'retail_portfolio_id': 'c6178073-3d59-5f24-8d75-2df8c3d375c8', 'platform': 'ACCOUNT_PLATFORM_CONSUMER'},
#  {'uuid': '33d231b3-25e8-5403-94e6-ee0f1831ff14', 'name': 'BTC Wallet', 'currency': 'BTC', 'available_balance': {'value': '0.0006807682183481', 'currency': 'BTC'}, 'default': True, 'active': True, 'created_at': '2021-06-19T02:52:03.202Z', 'updated_at': '2024-11-24T20:28:32.918Z', 'deleted_at': None, 'type': 'ACCOUNT_TYPE_CRYPTO', 'ready': True, 'hold': {'value': '0', 'currency': 'BTC'}, 'retail_portfolio_id': 'c6178073-3d59-5f24-8d75-2df8c3d375c8', 'platform': 'ACCOUNT_PLATFORM_CONSUMER'}]

# %%
from datetime import datetime, timedelta

class CBGranularity:
    ONE_MINUTE = 'ONE_MINUTE'
    FIVE_MINUTE = 'FIVE_MINUTE'
    FIFTEEN_MINUTE = 'FIFTEEN_MINUTE'
    THIRTY_MINUTE = 'THIRTY_MINUTE'
    ONE_HOUR = 'ONE_HOUR'
    TWO_HOUR = 'TWO_HOUR'
    SIX_HOUR = 'SIX_HOUR'
    ONE_DAY = 'ONE_DAY'

# Get the price history for a specific product (e.g., BTC-USD)
product_id = 'BTC-USD'
end = datetime.utcnow()
start = end - timedelta(days=1)
granularity = '3600'  # 1 hour
start_timestamp = str(int(start.timestamp()))
end_timestamp = str(int(end.timestamp()))
price_history = client.get_candles(product_id, start=start_timestamp, end=end_timestamp, granularity=CBGranularity.FIFTEEN_MINUTE)

# Print the price history
pprint(price_history.candles, indent=2)
print(type(price_history.candles))
# Out:
# [ {'start': '1733193000', 'low': '95779.19', 'high': '95909.49', 'open': '95799.82', 'close': '95837.36', 'volume': '37.53213358'},
#   {'start': '1733192100', 'low': '95579.38', 'high': '95849.06', 'open': '95586.73', 'close': '95796.64', 'volume': '102.1606927'},
#   {'start': '1733191200', 'low': '95406.08', 'high': '95635.11', 'open': '95528.31', 'close': '95586.72', 'volume': '118.85152809'},
#   {'start': '1733190300', 'low': '95463.13', 'high': '95624.52', 'open': '95569.57', 'close': '95528.3', 'volume': '116.80993149'},
#   {'start': '1733189400', 'low': '95552.29', 'high': '95783.39', 'open': '95598.34', 'close': '95569.57', 'volume': '129.06514825'},
#   {'start': '1733188500', 'low': '95576', 'high': '95950.8', 'open': '95924.44', 'close': '95598.34', 'volume': '172.6563681'},
#   {'start': '1733187600', 'low': '95686.84', 'high': '95932.81', 'open': '95816.25', 'close': '95924.45', 'volume': '146.74489474'},
#   {'start': '1733186700', 'low': '95804.37', 'high': '96138.23', 'open': '95995.12', 'close': '95814.57', 'volume': '240.44569256'},
#   {'start': '1733185800', 'low': '95703.43', 'high': '96117.12', 'open': '95797.31', 'close': '95995.56', 'volume': '155.27867077'},
#   {'start': '1733184900', 'low': '95735.54', 'high': '96069', 'open': '95987.21', 'close': '95797.31', 'volume': '159.37094911'},
#   {'start': '1733184000', 'low': '95717.03', 'high': '96047.79', 'open': '95862.89', 'close': '95987.2', 'volume': '127.80481731'},
#   {'start': '1733183100', 'low': '95622.76', 'high': '95885', 'open': '95699.36', 'close': '95862.89', 'volume': '121.24398172'},
#   {'start': '1733182200', 'low': '95620.29', 'high': '95810.61', 'open': '95724.14', 'close': '95699.36', 'volume': '127.68525112'},
#   {'start': '1733181300', 'low': '95510.16', 'high': '95738', 'open': '95543.14', 'close': '95724.15', 'volume': '123.36003948'},
#   {'start': '1733180400', 'low': '95348.17', 'high': '95628.21', 'open': '95404.39', 'close': '95545.31', 'volume': '200.44643068'},
#   {'start': '1733179500', 'low': '95259.81', 'high': '95493.61', 'open': '95387.69', 'close': '95404.4', 'volume': '132.52397037'},
#   {'start': '1733178600', 'low': '95110.93', 'high': '95491.29', 'open': '95309.83', 'close': '95388.25', 'volume': '131.19886032'},
#   {'start': '1733177700', 'low': '95277.87', 'high': '95554.36', 'open': '95409.5', 'close': '95309.82', 'volume': '157.55336816'},
#   {'start': '1733176800', 'low': '95288.21', 'high': '95540.38', 'open': '95413.09', 'close': '95409.5', 'volume': '190.16697038'},
#   {'start': '1733175900', 'low': '95400', 'high': '95767.98', 'open': '95628.16', 'close': '95413.09', 'volume': '207.77375237'},
#   {'start': '1733175000', 'low': '95340.18', 'high': '95660.03', 'open': '95617.59', 'close': '95628.16', 'volume': '198.13786211'},
#   {'start': '1733174100', 'low': '95392.98', 'high': '95683.03', 'open': '95569.72', 'close': '95617.58', 'volume': '266.45399496'},
#   {'start': '1733173200', 'low': '95419.22', 'high': '95750.69', 'open': '95694.33', 'close': '95569.72', 'volume': '179.69135722'},
#   {'start': '1733172300', 'low': '95468.66', 'high': '95807.38', 'open': '95718.86', 'close': '95694.32', 'volume': '371.75611054'},
#   {'start': '1733171400', 'low': '95707.03', 'high': '96093.93', 'open': '96060.58', 'close': '95718.86', 'volume': '267.28186739'},
#   {'start': '1733170500', 'low': '96010.74', 'high': '96367.45', 'open': '96251.92', 'close': '96055.06', 'volume': '228.61661506'},
#   {'start': '1733169600', 'low': '95792.72', 'high': '96298.95', 'open': '95832.31', 'close': '96251.93', 'volume': '290.50998171'},
#   {'start': '1733168700', 'low': '95604.11', 'high': '95870.1', 'open': '95693.75', 'close': '95832.31', 'volume': '249.16461515'},
#   {'start': '1733167800', 'low': '95362.9', 'high': '95807.93', 'open': '95466.79', 'close': '95693.35', 'volume': '280.21153814'},
#   {'start': '1733166900', 'low': '95168.02', 'high': '95490.28', 'open': '95385.03', 'close': '95466.79', 'volume': '276.45692139'},
#   {'start': '1733166000', 'low': '95238.19', 'high': '95666.66', 'open': '95666.66', 'close': '95384.98', 'volume': '237.67930675'},
#   {'start': '1733165100', 'low': '95581.08', 'high': '95850', 'open': '95773.03', 'close': '95663.73', 'volume': '266.65009246'},
#   {'start': '1733164200', 'low': '95392.17', 'high': '95880', 'open': '95531.52', 'close': '95773.03', 'volume': '246.9913493'},
#   {'start': '1733163300', 'low': '95275.67', 'high': '95638.34', 'open': '95402.16', 'close': '95531.52', 'volume': '334.33436709'},
#   {'start': '1733162400', 'low': '94492.8', 'high': '95442.93', 'open': '94627.47', 'close': '95402.16', 'volume': '331.80538926'},
#   {'start': '1733161500', 'low': '94400.63', 'high': '95516.09', 'open': '95496.81', 'close': '94623.07', 'volume': '437.45778582'},
#   {'start': '1733160600', 'low': '95087.45', 'high': '95500', 'open': '95431.23', 'close': '95496.81', 'volume': '410.13884521'},
#   {'start': '1733159700', 'low': '95422.01', 'high': '96382.85', 'open': '96313.86', 'close': '95438.38', 'volume': '292.16072653'},
#   {'start': '1733158800', 'low': '96140.5', 'high': '96640.34', 'open': '96219.29', 'close': '96313.84', 'volume': '318.17968991'},
#   {'start': '1733157900', 'low': '96118.03', 'high': '96615.81', 'open': '96457.56', 'close': '96219.29', 'volume': '286.67160886'},
#   {'start': '1733157000', 'low': '96056.55', 'high': '96992.15', 'open': '96674.42', 'close': '96457.95', 'volume': '365.4216863'},
#   {'start': '1733156100', 'low': '96665.36', 'high': '97445', 'open': '97343.39', 'close': '96674.41', 'volume': '392.47513427'},
#   {'start': '1733155200', 'low': '96971.8', 'high': '97440.93', 'open': '97116.49', 'close': '97343.4', 'volume': '344.90984456'},
#   {'start': '1733154300', 'low': '96837.51', 'high': '97296.88', 'open': '97224.01', 'close': '97116.49', 'volume': '358.29416216'},
#   {'start': '1733153400', 'low': '96633.36', 'high': '97271.84', 'open': '96736.66', 'close': '97224.01', 'volume': '463.91643452'},
#   {'start': '1733152500', 'low': '96514.82', 'high': '97116.4', 'open': '96516.36', 'close': '96736.73', 'volume': '641.9552673'},
#   {'start': '1733151600', 'low': '95788.49', 'high': '96657.89', 'open': '96393.13', 'close': '96516.33', 'volume': '565.38769395'},
#   {'start': '1733150700', 'low': '96178.06', 'high': '96879.47', 'open': '96774.71', 'close': '96393.12', 'volume': '347.18803363'},
#   {'start': '1733149800', 'low': '95928.4', 'high': '96854.05', 'open': '95944.06', 'close': '96774.36', 'volume': '482.94956753'},
#   {'start': '1733148900', 'low': '95532.01', 'high': '95975.95', 'open': '95609.3', 'close': '95944.06', 'volume': '120.81801227'},
#   {'start': '1733148000', 'low': '95552.83', 'high': '95810', 'open': '95701.01', 'close': '95609.3', 'volume': '71.16078621'},
#   {'start': '1733147100', 'low': '95500.02', 'high': '95794.93', 'open': '95602.42', 'close': '95701.01', 'volume': '91.77047909'},
#   {'start': '1733146200', 'low': '95572.58', 'high': '95826.56', 'open': '95711.03', 'close': '95589.5', 'volume': '100.98597512'},
#   {'start': '1733145300', 'low': '95380.3', 'high': '95749.99', 'open': '95398.78', 'close': '95708.94', 'volume': '103.17490466'},
#   {'start': '1733144400', 'low': '94828.56', 'high': '95482.6', 'open': '94982.43', 'close': '95398.78', 'volume': '115.12490593'},
#   {'start': '1733143500', 'low': '94782', 'high': '95099.67', 'open': '95076.2', 'close': '94989', 'volume': '78.08230108'},
#   {'start': '1733142600', 'low': '95075.57', 'high': '95414.35', 'open': '95384.48', 'close': '95081.39', 'volume': '120.53061511'},
#   {'start': '1733141700', 'low': '95023.64', 'high': '95399.99', 'open': '95122.6', 'close': '95384.47', 'volume': '130.05188621'},
#   {'start': '1733140800', 'low': '94956.58', 'high': '95180.89', 'open': '95130.57', 'close': '95122.59', 'volume': '110.21095793'},
#   {'start': '1733139900', 'low': '94946.67', 'high': '95258.44', 'open': '95206.45', 'close': '95133.01', 'volume': '66.64036151'},
#   {'start': '1733139000', 'low': '95157.04', 'high': '95344.63', 'open': '95270.09', 'close': '95210.01', 'volume': '51.55686631'},
#   {'start': '1733138100', 'low': '95078.17', 'high': '95336.55', 'open': '95086.48', 'close': '95270.09', 'volume': '63.95709238'},
#   {'start': '1733137200', 'low': '94862.85', 'high': '95147.24', 'open': '94968.92', 'close': '95081.51', 'volume': '45.40087128'},
#   {'start': '1733136300', 'low': '94830.14', 'high': '95200.64', 'open': '94940.41', 'close': '94989.04', 'volume': '51.44261948'},
#   {'start': '1733135400', 'low': '94900.01', 'high': '95251.59', 'open': '95207.97', 'close': '94939.31', 'volume': '49.93773231'},
#   {'start': '1733134500', 'low': '95036.11', 'high': '95230.47', 'open': '95152.87', 'close': '95224.13', 'volume': '47.9487022'},
#   {'start': '1733133600', 'low': '95125.55', 'high': '95538.05', 'open': '95523.78', 'close': '95142.06', 'volume': '55.33861309'},
#   {'start': '1733132700', 'low': '95138.01', 'high': '95576.05', 'open': '95195.53', 'close': '95514.23', 'volume': '48.00734294'},
#   {'start': '1733131800', 'low': '95097.32', 'high': '95416.02', 'open': '95330.21', 'close': '95195.53', 'volume': '48.88932318'},
#   {'start': '1733130900', 'low': '95167', 'high': '95430.99', 'open': '95383.27', 'close': '95330.24', 'volume': '118.44444358'},
#   {'start': '1733130000', 'low': '94977.38', 'high': '95395.27', 'open': '95073.03', 'close': '95383.28', 'volume': '115.48667317'},
#   {'start': '1733129100', 'low': '94928.82', 'high': '95329.58', 'open': '95095.12', 'close': '95074.66', 'volume': '99.1170922'},
#   {'start': '1733128200', 'low': '94923.83', 'high': '95434.75', 'open': '95254.78', 'close': '95109.68', 'volume': '115.46310633'},
#   {'start': '1733127300', 'low': '95204.24', 'high': '96012.8', 'open': '95974.3', 'close': '95254.78', 'volume': '151.01756766'},
#   {'start': '1733126400', 'low': '95849.67', 'high': '96164.99', 'open': '96048.31', 'close': '95974.29', 'volume': '35.87032866'},
#   {'start': '1733125500', 'low': '95964.84', 'high': '96108.25', 'open': '96023.52', 'close': '96048.31', 'volume': '22.70577305'}]
# <class 'list'>

# %%
def coinbase_candles_to_df(resp: GetProductCandlesResponse) -> pd.DataFrame:
    df = pd.DataFrame.from_records(resp.to_dict()['candles'])
    df['time'] = pd.to_datetime(df['start'], unit='s')
    return df


def coinbase_price_history(product_id: str, bar_count: int, granularity: CBGranularity) -> pd.DataFrame:
    start_timestamp = str(int(start.timestamp()))
    end_timestamp = str(int(end.timestamp()))
    price_history = client.get_candles(product_id, start=start_timestamp, end=end_timestamp, granularity=granularity)

# %%
import source.code.coinbase as cb
from source.code.coinbase import FetchConfig

cb.get_price_history('ETH-USD', 1000, fetch_config=FetchConfig('ONE_DAY', timedelta(days=1)), end_date=None)
# Out:
# /home/brian/Documents/cdp_api_key.json
# /home/brian/repos/streamlit-stock-gui/source/code/coinbase.py:93: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   price_data['start'] = pd.to_datetime(price_data['start'], unit='s', origin='unix')
# /home/brian/repos/streamlit-stock-gui/source/code/coinbase.py:93: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   price_data['start'] = pd.to_datetime(price_data['start'], unit='s', origin='unix')
# /home/brian/repos/streamlit-stock-gui/source/code/coinbase.py:93: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   price_data['start'] = pd.to_datetime(price_data['start'], unit='s', origin='unix')
#       Datetime      low     high     open    close         volume
# 0   2022-03-10  2553.42  2734.33  2727.86  2608.22  181463.078859
# 1   2022-03-11  2523.28  2679.56  2608.46  2556.42  155353.980266
# 2   2022-03-12  2552.52  2617.83  2556.39  2569.30   56451.093173
# 3   2022-03-13  2492.98  2603.56  2569.09  2516.41   71303.494920
# 4   2022-03-14  2499.00  2609.56  2516.42  2590.23  133881.301680
# ..         ...      ...      ...      ...      ...            ...
# 995 2024-11-29  3536.44  3650.00  3579.48  3593.67  137566.646517
# 996 2024-11-30  3569.63  3740.63  3593.38  3706.35   93227.763980
# 997 2024-12-01  3661.12  3748.29  3706.35  3710.24   81383.915444
# 998 2024-12-02  3556.03  3762.72  3710.08  3644.52  175600.094497
# 999 2024-12-03  3608.56  3654.47  3644.51  3636.03   13176.971796
#
# [1000 rows x 6 columns]

# %%
from source.code.yfinance_fetch import get_price_history
import matplotlib.pyplot as plt
gc = get_price_history('GC=F', 3000, fetch_config=FetchConfig('1d', timedelta(days=1)), end_date=None).set_index('Datetime')
cl = get_price_history('CL=F', 3000, fetch_config=FetchConfig('1d', timedelta(days=1)), end_date=None).set_index('Datetime')
cl.close.plot()
(cl / gc)[['close']].plot()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# <Axes: xlabel='Datetime'>

# %%
import numpy as np
eth = get_price_history('ETH-USD', 3000, fetch_config=FetchConfig('1d', timedelta(days=1)), end_date=None).set_index('Datetime')
btc = get_price_history('BTC-USD', 3000, fetch_config=FetchConfig('1d', timedelta(days=1)), end_date=None).set_index('Datetime')
close_prices = pd.concat([eth.close, btc.close], axis=1).dropna()
close_prices.columns = ['ETH', 'BTC']
close_prices.ETH = np.log(eth.close / eth.close.shift(1)).cumsum() + 2
close_prices.BTC = np.log(btc.close / btc.close.shift(1)).cumsum()
close_prices = close_prices.dropna()
close_prices['ratio'] = close_prices.ETH - close_prices.BTC
# close_prices = close_prices / close_prices.iloc[0] * 10
close_prices.plot(secondary_y=['ratio'])
close_prices
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                                 ETH       BTC     ratio
# Datetime
# 2017-11-09 19:00:00-05:00  1.930210  2.388786 -0.458576
# 2017-11-10 19:00:00-05:00  1.980480  2.348622 -0.368142
# 2017-11-11 19:00:00-05:00  1.958721  2.282374 -0.323653
# 2017-11-12 19:00:00-05:00  1.986926  2.379884 -0.392958
# 2017-11-13 19:00:00-05:00  2.050874  2.391443 -0.340569
# ...                             ...       ...       ...
# 2024-11-26 19:00:00-05:00  4.433387  5.062929 -0.629542
# 2024-11-27 19:00:00-05:00  4.411986  5.059693 -0.647707
# 2024-11-28 19:00:00-05:00  4.415801  5.078429 -0.662628
# 2024-11-29 19:00:00-05:00  4.446549  5.067986 -0.621437
# 2024-11-30 19:00:00-05:00  4.448021  5.076562 -0.628541
#
# [2579 rows x 3 columns]

# %%
import source.code.settings as settings
# %matplotlib inline
import matplotlib.pyplot as plt
from datetime import datetime
import pandas as pd

fetcher = settings.source_settings.get('coinbase')
num_bars = 1000
end_date = datetime.now().replace(second=0, microsecond=0)
data = fetcher.get_price_history('ETH-USD', num_bars, fetch_config=fetcher.get('5 minute'), end_date=end_date - fetcher.get('5 minute').timedelta)

data = data.set_index('Datetime')

assert not data.index.duplicated().any(), "There are duplicate entries in the datetime index"
assert len(data) == num_bars, f"Expected {num_bars} bars, got {len(data)}"
# Assert that there are no gaps in the datetime index
assert data.index.to_series().diff().dropna().eq(pd.Timedelta('5T')).all(), "There are gaps in the datetime index"

data.close.plot()
# Out:
# /home/brian/repos/streamlit-stock-gui/source/code/coinbase.py:93: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   price_data['start'] = pd.to_datetime(price_data['start'], unit='s', origin='unix')
# /home/brian/repos/streamlit-stock-gui/source/code/coinbase.py:93: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   price_data['start'] = pd.to_datetime(price_data['start'], unit='s', origin='unix')
# /home/brian/repos/streamlit-stock-gui/source/code/coinbase.py:93: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   price_data['start'] = pd.to_datetime(price_data['start'], unit='s', origin='unix')
# /tmp/ipykernel_107680/1579806072.py:17: FutureWarning: 'T' is deprecated and will be removed in a future version. Please use 'min' instead of 'T'.
#   assert data.index.to_series().diff().dropna().eq(pd.Timedelta('5T')).all(), "There are gaps in the datetime index"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 19
#      16 # Assert that there are no gaps in the datetime index
#      17 assert data.index.to_series().diff().dropna().eq(pd.Timedelta('5T')).all(), "There are gaps in the datetime index"
# ---> 19 data.close.plot()
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:507, in MPLPlot.generate(self)
#     504 self._adorn_subplots(fig)
#     506 for ax in self.axes:
# --> 507     self._post_plot_logic_common(ax)
#     508     self._post_plot_logic(ax, self.data)
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:720, in MPLPlot._post_plot_logic_common(self, ax)
#     718 """Common post process for each axes"""
#     719 if self.orientation == "vertical" or self.orientation is None:
# --> 720     type(self)._apply_axis_properties(
#     721         ax.xaxis, rot=self.rot, fontsize=self.fontsize
#     722     )
#     723     type(self)._apply_axis_properties(ax.yaxis, fontsize=self.fontsize)
#     725     if hasattr(ax, "right_ax"):
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:822, in MPLPlot._apply_axis_properties(axis, rot, fontsize)
#     814 """
#     815 Tick creation within matplotlib is reasonably expensive and is
#     816 internally deferred until accessed as Ticks are created/destroyed
#     817 multiple times per draw. It's therefore beneficial for us to avoid
#     818 accessing unless we will act on the Tick.
#     819 """
#     820 if rot is not None or fontsize is not None:
#     821     # rot=0 is a valid setting, hence the explicit None check
# --> 822     labels = axis.get_majorticklabels() + axis.get_minorticklabels()
#     823     for label in labels:
#     824         if rot is not None:
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/matplotlib/axis.py:1460, in Axis.get_majorticklabels(self)
#    1458 def get_majorticklabels(self):
#    1459     """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1460     self._update_ticks()
#    1461     ticks = self.get_major_ticks()
#    1462     labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/matplotlib/axis.py:1307, in Axis._update_ticks(self)
#    1305     tick.label1.set_text(label)
#    1306     tick.label2.set_text(label)
# -> 1307 minor_locs = self.get_minorticklocs()
#    1308 minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1309 minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/matplotlib/axis.py:1536, in Axis.get_minorticklocs(self)
#    1534 """Return this Axis' minor tick locations in data coordinates."""
#    1535 # Remove minor ticks duplicating major ticks.
# -> 1536 minor_locs = np.asarray(self.minor.locator())
#    1537 if self.remove_overlapping_locs:
#    1538     major_locs = self.major.locator()
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/converter.py:1001, in TimeSeries_DateLocator.__call__(self)
#     999     vmin, vmax = vmax, vmin
#    1000 if self.isdynamic:
# -> 1001     locs = self._get_default_locs(vmin, vmax)
#    1002 else:  # pragma: no cover
#    1003     base = self.base
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/converter.py:986, in TimeSeries_DateLocator._get_default_locs(self, vmin, vmax)
#     984 def _get_default_locs(self, vmin, vmax):
#     985     """Returns the default locations of ticks."""
# --> 986     locator = self.finder(vmin, vmax, self.freq)
#     988     if self.isminor:
#     989         return np.compress(locator["min"], locator["val"])
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/converter.py:766, in _daily_finder(vmin, vmax, freq)
#     764 elif span <= 11 * periodsperyear:
#     765     year_start = _period_break(dates_, "year")
# --> 766     quarter_start = _period_break(dates_, "quarter")
#     767     info_maj[year_start] = True
#     768     info_min[quarter_start] = True
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/converter.py:525, in _period_break(dates, period)
#     514 def _period_break(dates: PeriodIndex, period: str) -> npt.NDArray[np.intp]:
#     515     """
#     516     Returns the indices where the given period changes.
#     517
#    (...)
#     523         Name of the period to monitor.
#     524     """
# --> 525     mask = _period_break_mask(dates, period)
#     526     return np.nonzero(mask)[0]
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/converter.py:530, in _period_break_mask(dates, period)
#     529 def _period_break_mask(dates: PeriodIndex, period: str) -> npt.NDArray[np.bool_]:
# --> 530     current = getattr(dates, period)
#     531     previous = getattr(dates - 1 * dates.freq, period)
#     532     return current != previous
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/pandas/core/indexes/extension.py:68, in _inherit_from_data.<locals>.fget(self)
#      67 def fget(self):
# ---> 68     result = getattr(self._data, name)
#      69     if wrap:
#      70         if isinstance(result, type(self._data)):
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/pandas/core/arrays/period.py:111, in _field_accessor.<locals>.f(self)
#     109 def f(self):
#     110     base = self.dtype._dtype_code
# --> 111     result = get_period_field_arr(name, self.asi8, base)
#     112     return result
#
# KeyboardInterrupt:

# %%
products = pd.DataFrame.from_records(client.get_products().to_dict()['products'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 products = pd.DataFrame.from_records(client.get_products().to_dict()['products'])
#
# NameError: name 'pd' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 price.Price.plot()
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1544, in LinePlot._make_plot(self, fig)
#    1541 label = self._mark_right_label(label, index=i)
#    1542 kwds["label"] = label
# -> 1544 newlines = plotf(
#    1545     ax,
#    1546     x,
#    1547     y,
#    1548     style=style,
#    1549     column_num=i,
#    1550     stacking_id=stacking_id,
#    1551     is_errorbar=is_errorbar,
#    1552     **kwds,
#    1553 )
#    1554 self._append_legend_handles_labels(newlines[0], label)
#    1556 if self._is_ts_plot():
#    1557     # reset of xlim should be used for ts data
#    1558     # TODO: GH28021, should find a way to change view limit on xaxis
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1604, in LinePlot._ts_plot(self, ax, x, data, style, **kwds)
#    1601 lines = self._plot(ax, data.index, np.asarray(data.values), style=style, **kwds)
#    1602 # set date formatter, locators and rescale limits
#    1603 # TODO #54485
# -> 1604 format_dateaxis(ax, ax.freq, data.index)  # type: ignore[arg-type, attr-defined]
#    1605 return lines
#
# File ~/repos/price-trend-analysis/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/timeseries.py:368, in format_dateaxis(subplot, freq, index)
#     366     subplot.xaxis.set_major_formatter(TimeSeries_TimedeltaFormatter())
#     367 else:
# --> 368     raise TypeError("index type not supported")
#     370 pylab.draw_if_interactive()
#
# TypeError: index type not supported

# %%
emissions = pd.read_excel('./src/code/emissions.ods', engine='odf')
emissions.head()
# Out:
#    Start Date  Epoch  Emissions Lock Ratio Unlock Ratio
# 0  14/09/2024      1  252805.79       100%           0%
# 1  23/09/2024      2  248128.89       100%           0%
# 2  30/09/2024      3  243538.50       100%           0%
# 3   7/10/2024      4  239033.04       100%           0%
# 4  14/10/2024      5  234610.93       100%           0%

# %%
emmission = 209744.25
apr = 93.6460
price = 1.77
v = 206147.20084146678

v1 = ((emmission*price) / (apr/52))
value = ((emmission*price*52) / (apr))
print('value', value)
emissions['apr'] = ((emissions.Emissions*price) / v) * 52

print(emissions.Emissions.sum())
emissions.iloc[10:]
# Out:
# value 206147.20084146678
# 8426859.760000002
#      Start Date  Epoch  Emissions Lock Ratio Unlock Ratio        apr
# 10   25/11/2024     11  209744.25        93%           7%  93.646000
# 11   02/12/2024     12  205863.98        91%           9%  91.913548
# 12  09/12/2024/     13  202055.50        89%          11%  90.213149
# 13   16/12/2024     14  198317.47        87%          13%  88.544205
# 14   23/12/2024     15  194648.60        85%          15%  86.906138
# 15   30/12/2024     16  191047.60        82%          18%  85.298374
# 16   06/01/2025     17  187513.22        79%          21%  83.720355
# 17   13/01/2025     18  184044.22        76%          24%  82.171526
# 18   20/01/2025     19  180639.40        73%          27%  80.651352
# 19   27/01/2025     20  177297.57        70%          30%  79.159301
# 20   03/02/2025     21  174017.57        65%          35%  77.694856
# 21   10/02/2025     22  170798.24        60%          40%  76.257499
# 22   17/02/2025     23  167638.48        55%          45%  74.846739
# 23   24/02/2025     24  164537.17        50%          50%  73.462075
# 24   03/03/2025     25  161493.23        45%          55%  72.103026
# 25   10/03/2025     26  158505.60        37%          63%  70.769117
# 26   17/03/2025     27  155573.25        29%          71%  69.459890
# 27   24/03/2025     28  152695.14        21%          79%  68.174880
# 28   31/03/2025     29  149870.28        13%          87%  66.913645
# 29   07/04/2025     30  147097.68         0%         100%  65.675742
# 30   14/04/2025     31  144376.38         0%         100%  64.460744
# 31   21/04/2025     32  141705.41         0%         100%  63.268217
# 32   28/04/2025     33  139083.86         0%         100%  62.097755
# 33   05/05/2025     34  136510.81         0%         100%  60.948948
# 34   12/05/2025     35  133985.36         0%         100%  59.821392
# 35   19/05/2025     36  131506.63         0%         100%  58.714696
# 36   26/05/2025     37  129073.76         0%         100%  57.628475
# 37   02/06/2025     38  126685.90         0%         100%  56.562351
# 38   09/06/2025     39  124342.21         0%         100%  55.515947
# 39   16/06/2025     40  122041.88         0%         100%  54.488902
# 40   23/06/2025     41  119784.10         0%         100%  53.480855
# 41   30/06/2025     42  117568.10         0%         100%  52.491462
# 42   07/07/2025     43  115393.09         0%         100%  51.520370
# 43   14/07/2025     44  113258.31         0%         100%  50.567239
# 44   21/07/2025     45  111163.03         0%         100%  49.631745
# 45   28/07/2025     46  109106.52         0%         100%  48.713560
# 46   04/08/2025     47  107088.05         0%         100%  47.812360
# 47   11/08/2025     48  105106.92         0%         100%  46.927831
# 48   18/08/2025     49  103162.44         0%         100%  46.059665
# 49   25/08/2025     50  101253.94         0%         100%  45.207563
# 50   01/09/2025     51   99380.74         0%         100%  44.371222
# 51   08/09/2025     52   34232.82         0%         100%  15.284169
